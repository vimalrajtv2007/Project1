# %%
import pandas as pd

# %%
# lord the dadaset
df = pd.read_csv('walmartcsv.csv')

# %%
df.head()
# Out:
#    Store        Date     Weekly_Sales  Holiday_Flag  Temperature Fuel_Price  \
# 0      1  05-02-2010   $16,43,690.90              0        42.31      $2.57
# 1      1  12-02-2010   $16,41,957.44              1        38.51      $2.55
# 2      1  19-02-2010   $16,11,968.17              0        39.93      $2.51
# 3      1  26-02-2010   $14,09,727.59              0        46.63      $2.56
# 4      1  05-03-2010   $15,54,806.68              0        46.50      $2.63
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.head
# Out:
#    Store        Date     Weekly_Sales  Holiday_Flag  Temperature Fuel_Price  \
# 0      1  05-02-2010   $16,43,690.90              0        42.31      $2.57
# 1      1  12-02-2010   $16,41,957.44              1        38.51      $2.55
# 2      1  19-02-2010   $16,11,968.17              0        39.93      $2.51
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106

# %%
df.tail(2)
# Out:
#       Store        Date    Weekly_Sales  Holiday_Flag  Temperature Fuel_Price  \
# 6433     45  19-10-2012   $7,18,125.53              0        56.47      $3.97
# 6434     45  26-10-2012   $7,60,281.43              0        58.85      $3.88
#
#              CPI  Unemployment
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
df.shape
# Out:
# (6435, 8)

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Store        Date     Weekly_Sales  Holiday_Flag  Temperature  \
# 0         1  05-02-2010   $16,43,690.90              0        42.31
# 1         1  12-02-2010   $16,41,957.44              1        38.51
# 2         1  19-02-2010   $16,11,968.17              0        39.93
# 3         1  26-02-2010   $14,09,727.59              0        46.63
# 4         1  05-03-2010   $15,54,806.68              0        46.50
# ...     ...         ...              ...           ...          ...
# 6430     45  28-09-2012    $7,13,173.95              0        64.88
# 6431     45  05-10-2012    $7,33,455.07              0        64.89
# 6432     45  12-10-2012    $7,34,464.36              0        54.47
# 6433     45  19-10-2012    $7,18,125.53              0        56.47
# 6434     45  26-10-2012    $7,60,281.43              0        58.85
#
#      Fuel_Price         CPI  Unemployment
# 0         $2.57  211.096358         8.106
# ...
